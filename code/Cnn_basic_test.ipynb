# %%
import tensorflow as tf
import numpy as np

fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
print(train_images.dtype)
print(type(train_images))
# Out:
# uint8
# <class 'numpy.ndarray'>

# %%
print(train_labels.dtype)
print(type(train_labels))
# Out:
# uint8
# <class 'numpy.ndarray'>

# %%
import cv2

cv2.imshow("a", train_images[0])
# if cv2.waitKey()==27:
#     cv2.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\moons\Desktop\Python code\sign_language\Cnn_basic_test.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/moons/Desktop/Python%20code/sign_language/Cnn_basic_test.ipynb#ch0000023?line=0'>1</a> import cv2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/moons/Desktop/Python%20code/sign_language/Cnn_basic_test.ipynb#ch0000023?line=2'>3</a> cv2.imshow("a", train_images[0])
#
# NameError: name 'train_images' is not defined

# %%
train_labels.shape
# Out:
# (60000,)

# %%
for i in range(10):
    print(train_labels[i])
# Out:
# 9
# 0
# 0
# 3
# 0
# 2
# 7
# 2
# 5
# 5

# %%
import matplotlib.pyplot as plt

print(train_images[13].shape)
plt.figure()
plt.imshow(train_images[13],cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# (28, 28)

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4937 - accuracy: 0.8267
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3752 - accuracy: 0.8647
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3353 - accuracy: 0.8774
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3128 - accuracy: 0.8849
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2949 - accuracy: 0.8917
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2806 - accuracy: 0.8956
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2665 - accuracy: 0.9006
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2550 - accuracy: 0.9047
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2482 - accuracy: 0.9067
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2383 - accuracy: 0.9114

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.3294 - accuracy: 0.8861 - 495ms/epoch - 2ms/step
#
# Test accuracy: 0.8860999941825867

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([2.0269012e-07, 5.2813087e-10, 9.4760120e-09, 1.4636601e-14,
#        2.6213584e-10, 9.2789596e-05, 7.9310611e-09, 1.9664636e-03,
#        6.4573313e-10, 9.9794048e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %%
# Grab an image from the test dataset.
img = test_images[1]

print(img.shape)
# Out:
# (28, 28)
